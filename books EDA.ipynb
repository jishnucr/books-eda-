# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B233-0680
#
#  Directory of C:\data science\books EDA
#
# 11-12-2023  14:22    <DIR>          .
# 12-12-2023  14:31    <DIR>          ..
# 11-12-2023  11:36    <DIR>          .ipynb_checkpoints
# 11-12-2023  14:22           176,254 books EDA.ipynb
# 11-12-2023  11:35           162,139 Books_Data_Clean.csv
#                2 File(s)        338,393 bytes
#                3 Dir(s)  229,484,720,128 bytes free

# %%
data = pd.read_csv("Books_Data_Clean.csv")

# %%
data
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
data.shape
# Out:
# (1070, 15)

# %%
data.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
data[["Publishing Year","Book Name","language_code"]].isnull().sum()
# Out:
# Publishing Year     1
# Book Name          23
# language_code      53
# dtype: int64

# %% [markdown]
# **book information**
# - Publishing Year
# - Book Name
# - Author
# - language_code
# - genre
# - data.columns

# %% [markdown]
# **book perfomance details**
# - Author_Rating
# - Book_average_rating
# - Book_ratings_count
# - gross sales
# - publisher revenue
# - units sold

# %% [markdown]
# **book price details**
# - sale price
# - sales rank

# %% [markdown]
# ## Book info

# %%
book_info=data[["Publishing Year","Book Name","Author","language_code","genre"]]

# %%
book_info
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# ...

# %%
book_info["Publishing Year"].value_counts()
# Out:
# 2012.0    68
# 2011.0    55
# 2009.0    46
# 2010.0    44
# 2006.0    41
#           ..
# 1916.0     1
# 1320.0     1
# 1667.0     1
# 1964.0     1
# 1879.0     1
# Name: Publishing Year, Length: 150, dtype: int64

# %% [markdown]
# - maximum books was published in year 2012 which is 2016

# %%
book_info["Publishing Year"].between(2000,2010).sum()
# Out:
# 378

# %%
book_info["Publishing Year"].between(1900,2000).sum()
# Out:
# 427

# %%
book_info["Publishing Year"].between(1800,1900).sum()
# Out:
# 41

# %%
book_info["Publishing Year"].describe()
# Out:
# count    1069.000000
# mean     1971.377923
# std       185.080257
# min      -560.000000
# 25%      1985.000000
# 50%      2003.000000
# 75%      2010.000000
# max      2016.000000
# Name: Publishing Year, dtype: float64

# %%
sns.scatterplot(book_info["Publishing Year"])
# Out:
# <Axes: ylabel='Publishing Year'>

# %%
book_info
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# ...

# %%
book_info["Author"].value_counts()
# Out:
# Stephen King                                              29
# John Grisham                                              13
# Jodi Picoult                                              11
# Charlaine Harris                                          10
# Jim Butcher                                               10
#                                                           ..
# Nora Roberts                                               1
# John Scalzi                                                1
# Irma S. Rombauer, Marion Rombauer Becker, Ethan Becker     1
# Joe Haldeman                                               1
# Dashiell Hammett                                           1
# Name: Author, Length: 735, dtype: int64

# %% [markdown]
# - stephen King was the author who published more books in this data set

# %%
author_group=book_info.groupby("Author")["Book Name"]

# %%
author_group.get_group("Stephen King")
# Out:
# 22                            Needful Things
# 25                                      Cujo
# 78                                      Cell
# 81                  The Drawing of the Three
# 92                              Mr. Mercedes
# 139                            The Dead Zone
# 144                              Firestarter
# 160        On Writing: A Memoir of the Craft
# 172                             Bag of Bones
# 208                        Different Seasons
# 263                             Doctor Sleep
# 380                            Gerald's Game
# 413                              Desperation
# 422                           The Dark Tower
# 436                            The Dark Half
# 455            The Girl Who Loved Tom Gordon
# 592                            Skeleton Crew
# 608                        The Tommyknockers
# 651                                  Joyland
# 677                       Four Past Midnight
# 730                       Eyes of the Dragon
# ...

# %% [markdown]
# - so here we have the books written by Stephen King who published more books in the data

# %%
book_info.columns
# Out:
# Index(['Publishing Year', 'Book Name', 'Author', 'language_code', 'genre'], dtype='object')

# %%
book_info.isnull().sum()
# Out:
# Publishing Year     1
# Book Name          23
# Author              0
# language_code      53
# genre               0
# dtype: int64

# %%
book_info.fillna(0)
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# ...

# %%
book_info=data[["Publishing Year","Book Name","Author","language_code","genre"]]

# %%
book_info["language_code"].value_counts()
# Out:
# eng      737
# en-US    234
# en-GB     30
# en-CA      7
# fre        4
# spa        2
# ara        2
# nl         1
# Name: language_code, dtype: int64

# %%
book_info.columns
# Out:
# Index(['Publishing Year', 'Book Name', 'Author', 'language_code', 'genre'], dtype='object')

# %%
stephen = author_group.get_group("Stephen King")

# %%
stephen
# Out:
# 22                            Needful Things
# 25                                      Cujo
# 78                                      Cell
# 81                  The Drawing of the Three
# 92                              Mr. Mercedes
# 139                            The Dead Zone
# 144                              Firestarter
# 160        On Writing: A Memoir of the Craft
# 172                             Bag of Bones
# 208                        Different Seasons
# 263                             Doctor Sleep
# 380                            Gerald's Game
# 413                              Desperation
# 422                           The Dark Tower
# 436                            The Dark Half
# 455            The Girl Who Loved Tom Gordon
# 592                            Skeleton Crew
# 608                        The Tommyknockers
# 651                                  Joyland
# 677                       Four Past Midnight
# 730                       Eyes of the Dragon
# ...

# %%
genre=book_info.groupby("Author")["genre","Book Name"]
genre.get_group("Stephen King")
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\1696969069.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   genre=book_info.groupby("Author")["genre","Book Name"]
#               genre                             Book Name
# 22    genre fiction                        Needful Things
# 25    genre fiction                                  Cujo
# 78    genre fiction                                  Cell
# 81       nonfiction              The Drawing of the Three
# 92    genre fiction                          Mr. Mercedes
# 139   genre fiction                         The Dead Zone
# 144   genre fiction                           Firestarter
# 160   genre fiction     On Writing: A Memoir of the Craft
# 172   genre fiction                          Bag of Bones
# 208   genre fiction                     Different Seasons
# 263   genre fiction                          Doctor Sleep
# ...

# %%
book_info
# Out:
#       Publishing Year                        Book Name  \
# 0              1975.0                          Beowulf
# 1              1987.0                 Batman: Year One
# 2              2015.0                Go Set a Watchman
# 3              2008.0  When You Are Engulfed in Flames
# 4              2011.0         Daughter of Smoke & Bone
# ...               ...                              ...
# 1065           2014.0                    Gray Mountain
# 1066           1989.0                 The Power of One
# 1067           1930.0               The Maltese Falcon
# 1068           2011.0                       Night Road
# 1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                            Harper Lee           eng
# ...

# %%
top_books=book_info.head(100)

# %%
pd.to_numeric(top_books['Publishing Year'], errors='coerce')
top_books["Publishing Year"] = top_books["Publishing Year"].astype(int)
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\2962694468.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_books["Publishing Year"] = top_books["Publishing Year"].astype(int)

# %%
top_books["Publishing Year"]
# Out:
# 0     1975
# 1     1987
# 2     2015
# 3     2008
# 4     2011
#       ...
# 95    1985
# 96    1989
# 97    1987
# 98    1998
# 99    2013
# Name: Publishing Year, Length: 100, dtype: int32

# %% [markdown]
# now lets check about the perfomance features

# %%
data.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
Author_Rating
Book_average_rating
Book_ratings_count
gross sales
publisher revenue
units sold
# Out:
#   Cell In[35], line 4
#     gross sales
#           ^
# SyntaxError: invalid syntax

# %%
perfo = data[["Book Name","Author","Author_Rating","Book_average_rating","Book_ratings_count","gross sales","publisher revenue","units sold"]]

# %%
author_rating=perfo.groupby("Author_Rating")["Author","Book Name"]
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\2009756954.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   author_rating=perfo.groupby("Author_Rating")["Author","Book Name"]

# %%
perfo
# Out:
#                             Book Name  \
# 0                             Beowulf
# 1                    Batman: Year One
# 2                   Go Set a Watchman
# 3     When You Are Engulfed in Flames
# 4            Daughter of Smoke & Bone
# ...                               ...
# 1065                    Gray Mountain
# 1066                 The Power of One
# 1067               The Maltese Falcon
# 1068                       Night Road
# 1069                         Tripwire
#
#                                                  Author Author_Rating  \
# 0                                Unknown, Seamus Heaney        Novice
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                            Harper Lee        Novice
# 3                                         David Sedaris  Intermediate
# 4                                          Laini Taylor  Intermediate
# ...                                                 ...           ...
# ...

# %%
novice = author_rating.get_group("Novice")

# %%
novice
# Out:
#                                                  Author  \
# 0                                Unknown, Seamus Heaney
# 2                                            Harper Lee
# 53                                         Lev Grossman
# 115                    Geoffrey Chaucer, Nevill Coghill
# 184                                       Arthur Miller
# 199                                      John Steinbeck
# 210                                        Melissa Bank
# 276                                         Dave Eggers
# 377                                        Jodi Picoult
# 393                                   Jeffrey Eugenides
# 395                                       Jessica Knoll
# 400                          Lena Dunham, Joana Avillez
# 470                            Herman Koch, Sam Garrett
# 508                     Seth Grahame-Smith, Jane Austen
# 545                             Cynthia D'Aprix Sweeney
# 554                                       Chetan Bhagat
# ...

# %%
rating=perfo[["Book_average_rating","Book_ratings_count"]]

# %%
rating.describe()
# Out:
#        Book_average_rating  Book_ratings_count
# count          1070.000000         1070.000000
# mean              4.007000        94909.913084
# std               0.247244        31513.242518
# min               2.970000        27308.000000
# 25%               3.850000        70398.000000
# 50%               4.015000        89309.000000
# 75%               4.170000       113906.500000
# max               4.770000       206792.000000

# %%
perfo.corr()
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\3253052181.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   perfo.corr()
#                      Book_average_rating  Book_ratings_count  gross sales  \
# Book_average_rating             1.000000            0.093033    -0.042240
# Book_ratings_count              0.093033            1.000000     0.502120
# gross sales                    -0.042240            0.502120     1.000000
# publisher revenue              -0.043510            0.401315     0.912891
# units sold                     -0.008516           -0.252232    -0.150592
#
#                      publisher revenue  units sold
# Book_average_rating          -0.043510   -0.008516
# Book_ratings_count            0.401315   -0.252232
# gross sales                   0.912891   -0.150592
# ...

# %%
perfo
# Out:
#                             Book Name  \
# 0                             Beowulf
# 1                    Batman: Year One
# 2                   Go Set a Watchman
# 3     When You Are Engulfed in Flames
# 4            Daughter of Smoke & Bone
# ...                               ...
# 1065                    Gray Mountain
# 1066                 The Power of One
# 1067               The Maltese Falcon
# 1068                       Night Road
# 1069                         Tripwire
#
#                                                  Author Author_Rating  \
# 0                                Unknown, Seamus Heaney        Novice
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                            Harper Lee        Novice
# 3                                         David Sedaris  Intermediate
# 4                                          Laini Taylor  Intermediate
# ...                                                 ...           ...
# ...

# %%
perfo.isna().sum()
# Out:
# Book Name              23
# Author                  0
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# gross sales             0
# publisher revenue       0
# units sold              0
# dtype: int64

# %%
plt.plot(perfo["units sold"])

# %%
perfo
# Out:
#                             Book Name  \
# 0                             Beowulf
# 1                    Batman: Year One
# 2                   Go Set a Watchman
# 3     When You Are Engulfed in Flames
# 4            Daughter of Smoke & Bone
# ...                               ...
# 1065                    Gray Mountain
# 1066                 The Power of One
# 1067               The Maltese Falcon
# 1068                       Night Road
# 1069                         Tripwire
#
#                                                  Author Author_Rating  \
# 0                                Unknown, Seamus Heaney        Novice
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                            Harper Lee        Novice
# 3                                         David Sedaris  Intermediate
# 4                                          Laini Taylor  Intermediate
# ...                                                 ...           ...
# ...

# %% [markdown]
# #### Distribution of Publisher Revenue (Univariate analysis)

# %%
sns.distplot(perfo["publisher revenue"],kde=True)
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\76551998.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(perfo["publisher revenue"],kde=True)
# <Axes: xlabel='publisher revenue', ylabel='Density'>

# %%
perfo["publisher revenue"].value_counts()
# Out:
# 0.000       372
# 70.686        6
# 68.904        5
# 67.122        5
# 200.928       4
#            ...
# 981.558       1
# 444.912       1
# 684.684       1
# 146.718       1
# 1291.836      1
# Name: publisher revenue, Length: 610, dtype: int64

# %%
revenue_max=perfo[perfo["publisher revenue"]==70.686]

# %%
revenue_max
# Out:
#                                              Book Name  \
# 655                                The Glass Menagerie
# 660                                          Ringworld
# 670                                     Dead Reckoning
# 673                                  The Invisible Man
# 674  ä¸–ç•Œã®çµ‚ã‚Šã¨ãƒãƒ¼ãƒ‰ãƒœã‚¤ãƒ«ãƒ‰ãƒ»ãƒ¯ã...
# 679                                    Anne of Avonlea
#
#                                Author Author_Rating  Book_average_rating  \
# 655                Tennessee Williams  Intermediate                 3.67
# 660                       Larry Niven  Intermediate                 3.96
# 670                  Charlaine Harris  Intermediate                 3.77
# 673                        H.G. Wells  Intermediate                 3.62
# 674  Haruki Murakami, Alfred Birnbaum     Excellent                 4.15
# 679                   L.M. Montgomery     Excellent                 4.21
#
# ...

# %%
revenue_max.plot(kind="bar",x="Book Name",y="Book_ratings_count",legend=True)
plt.title("Maximum revenue building books with their rating counts")
plt.xlabel("BookName")
plt.ylabel("RatingCount")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# C:\Users\91994\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# C:\Users\91994\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 143 (\x8f) missing from current font.
#   func(*args, **kwargs)
# C:\Users\91994\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\91994\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 143 (\x8f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
perfo.iloc[674,:]
# Out:
# Book Name              ä¸–ç•Œã®çµ‚ã‚Šã¨ãƒãƒ¼ãƒ‰ãƒœã‚¤ãƒ«ãƒ‰ãƒ»ãƒ¯ã...
# Author                                  Haruki Murakami, Alfred Birnbaum
# Author_Rating                                                  Excellent
# Book_average_rating                                                 4.15
# Book_ratings_count                                                 63764
# gross sales                                                       117.81
# publisher revenue                                                 70.686
# units sold                                                         38016
# Name: 674, dtype: object

# %% [markdown]
# #### we have a encoding problem the book name Doboirundo wanda which having the smaleest rating count

# %%
perfo
# Out:
#                             Book Name  \
# 0                             Beowulf
# 1                    Batman: Year One
# 2                   Go Set a Watchman
# 3     When You Are Engulfed in Flames
# 4            Daughter of Smoke & Bone
# ...                               ...
# 1065                    Gray Mountain
# 1066                 The Power of One
# 1067               The Maltese Falcon
# 1068                       Night Road
# 1069                         Tripwire
#
#                                                  Author Author_Rating  \
# 0                                Unknown, Seamus Heaney        Novice
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...  Intermediate
# 2                                            Harper Lee        Novice
# 3                                         David Sedaris  Intermediate
# 4                                          Laini Taylor  Intermediate
# ...                                                 ...           ...
# ...

# %%
perfo["gross sales"]
# Out:
# 0       34160.00
# 1       12437.50
# 2       47795.00
# 3       41250.00
# 4       37952.50
#           ...
# 1065      104.94
# 1066      846.94
# 1067      846.94
# 1068      104.94
# 1069      316.94
# Name: gross sales, Length: 1070, dtype: float64

# %%
sns.distplot(perfo["gross sales"],kde=True)
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\2876943692.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(perfo["gross sales"],kde=True)
# <Axes: xlabel='gross sales', ylabel='Density'>

# %%
sns.distplot(perfo["Book_average_rating"],kde=True)
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\2994427417.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(perfo["Book_average_rating"],kde=True)
# <Axes: xlabel='Book_average_rating', ylabel='Density'>

# %%
sns.distplot(perfo["units sold"])
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_10180\2808114468.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(perfo["units sold"])
# <Axes: xlabel='units sold', ylabel='Density'>

# %%
from scipy import stats

# %%
correlation=stats.pearsonr(perfo["Book_average_rating"],perfo["units sold"])[0]

# %%
np.around(correlation,4)
# Out:
# -0.0085

# %%
correlation
# Out:
# -0.008516131137630063

# %%
so average rating and units sold is having weak correlation
